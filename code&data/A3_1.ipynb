# %% [markdown]
# # Introduction

# %% [markdown]
# Unsplash dataset (a open-source images dataset) lite version is utilized for this model. The lite dataset includes 25,000 images, 25,000 keywords and 1,000,000 searches.

# %% [markdown]
# This page of code is for the realization of prediction model of nation estimation and photo recommendations. Some information are taken from Weijie Chen's a2, "Unsplash dataset exploration".

# %% [markdown]
# # Dataset loading

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import glob
from collections import Counter

# %%
path = './'
documents = ['photos', 'keywords', 'collections', 'conversions', 'colors']
datasets = {}
for doc in documents:
    files = glob.glob(path + doc + ".tsv*")
    subsets = []
    for filename in files:
        df = pd.read_csv(filename, sep='\t', header=0)
        subsets.append(df)

    datasets[doc] = pd.concat(subsets, axis=0, ignore_index=True)

# %% [markdown]
# # Data sorting

# %% [markdown]
# ## Color

# %% [markdown]
# Pick the top six colors for the prediction model

# %%
color_np = datasets['colors'].to_numpy()
color_name = color_np[:, 5]
top_colors_file = Counter(color_name.flat).most_common(10)
top_colors_file
# Out:
# [('darkslategray', 36493),
#  ('dimgray', 20776),
#  ('darkolivegreen', 17740),
#  ('black', 16149),
#  ('gray', 14245),
#  ('darkgray', 12816),
#  ('silver', 12558),
#  ('rosybrown', 11644),
#  ('saddlebrown', 7863),
#  ('sienna', 7313)]

# %% [markdown]
# ## Keyword

# %% [markdown]
# Pick the top six keywords for the prediction model

# %%
cnv_np = datasets['conversions'].to_numpy()
keyword_name = cnv_np[:, 2]
top_keyword_file = Counter(keyword_name.flat).most_common(24)
top_keyword_file
# Out:
# [('nature', 260985),
#  ('flowers', 152098),
#  ('natural', 148573),
#  ('mountain', 112230),
#  ('sea', 108634),
#  ('flower', 108199),
#  ('sky', 104738),
#  ('forest', 93503),
#  ('ocean', 80329),
#  ('dog', 78163),
#  ('space', 70042),
#  ('cat', 66788),
#  ('beach', 62631),
#  ('water', 55574),
#  ('summer', 52543),
#  ('mountains', 52003),
#  ('moon', 49961),
#  ('night', 49339),
#  ('landscape', 48172),
#  ('sunrise', 46574),
#  ('animal', 45840),
#  ('rain', 45796),
#  ('tree', 45648),
#  ('wood', 44947)]

# %% [markdown]
# Combine similar keywords together:
# 1. nature = 'nature' + 'natural'
# 2. flower = 'flowers' + 'flower'
# 3. sea = 'sea' + 'ocean'
#
# Then the top six keywords are:
# nature, flower, mountain, sea, sky, forest

# %% [markdown]
# # Camera preferences

# %% [markdown]
# Pick the top three camera brands for the prediction model

# %%
cmr_np = datasets['photos'].to_numpy()
camera_name = cmr_np[:, 12]
# resort the camera brand
new = []
for x in camera_name:
    if x==x:
        new.append((x.split()[0]).lower())
    else:
        new.append(x)
camera_name = new
top_camera_file = Counter(camera_name).most_common(3)
top_camera_file
# Out:
# [('canon', 8708), ('nikon', 4700), ('sony', 4052)]

# %% [markdown]
# Remove the nan data and the top ten camera brands for the prediction model would be: Canon, Nikon, Sony

# %% [markdown]
# # Map preparation

# %% [markdown]
# Prepare for the general introduction with maps. The first part is to generalize a map with highest-download-rate photo in each nation and the second part is to generalize a map with highest-download-rate photo in each nation and the specific keyword.

# %%
keyword_table = datasets['conversions'][['photo_id','keyword']]
country_table = datasets['photos'][['photo_id','photo_url','photo_location_country','photo_location_latitude','photo_location_longitude','stats_downloads','ai_description','photo_description']]
newkeyword = keyword_table.replace({'keyword':'natural'},{'keyword':'nature'}, regex=True)
newkeyword = newkeyword.replace({'keyword':'flowers'},{'keyword':'flower'}, regex=True)
newkeyword = newkeyword.replace({'keyword':'ocean'},{'keyword':'sea'}, regex=True)
keyword_table = newkeyword[newkeyword.keyword.isin(['nature', 'flower', 'mountain', 'sea', 'sky', 'forest'])]
newcountry = country_table.dropna(subset = ['photo_location_country'])
newcountry = newcountry.replace({'photo_location_country':'USA'},{'photo_location_country':'United States'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'美國'},{'photo_location_country':'United States'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Deutschland'},{'photo_location_country':'Germany'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Schweiz'},{'photo_location_country':'Switzerland'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Italien'},{'photo_location_country':'Italy'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Italia'},{'photo_location_country':'Italy'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Россия'},{'photo_location_country':'Russia'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Brasil'},{'photo_location_country':'Brazil'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'中国'},{'photo_location_country':'China'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Österreich'},{'photo_location_country':'Austria'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'México'},{'photo_location_country':'Mexico'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Latvija'},{'photo_location_country':'Latvia'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'España'},{'photo_location_country':'Spain'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Nederland'},{'photo_location_country':'Netherlands'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'日本'},{'photo_location_country':'Japan'}, regex=True)



country_table = newcountry

country_np = country_table.to_numpy()
country_name = country_np[:, 2]
country_name_file = Counter(country_name.flat).most_common(50)
country_name_file
# Out:
# [('United States', 2385),
#  ('Canada', 438),
#  ('Italy', 428),
#  ('United Kingdom', 424),
#  ('Germany', 379),
#  ('Australia', 341),
#  ('France', 292),
#  ('Iceland', 267),
#  ('Switzerland', 245),
#  ('Austria', 172),
#  ('Indonesia', 127),
#  ('Spain', 125),
#  ('Brazil', 119),
#  ('Russia', 118),
#  ('New Zealand', 112),
#  ('Portugal', 98),
#  ('Mexico', 90),
#  ('Netherlands', 85),
#  ('India', 75),
#  ('Norway', 75),
#  ('South Africa', 72),
#  ('Japan', 67),
#  ('China', 65),
#  ('Latvia', 63),
#  ('Maldives', 58),
#  ('Romania', 57),
#  ('Greece', 52),
#  ('Iran', 52),
#  ('Poland', 46),
#  ('Sweden', 46),
#  ('Vietnam', 38),
#  ('Thailand', 33),
#  ('Chile', 33),
#  ('Denmark', 32),
#  ('Ukraine', 30),
#  ('Argentina', 28),
#  ('Turkey', 28),
#  ('Hungary', 27),
#  ('Singapore', 26),
#  ('Philippines', 25),
#  ('Slovenia', 25),
#  ('Belgium', 24),
#  ('Costa Rica', 23),
#  ('Croatia', 23),
#  ('Hong Kong', 22),
#  ('Ireland', 22),
#  ('Finland', 22),
#  ('Taiwan', 22),
#  ('Morocco', 21),
#  ('Slovakia', 21)]

# %%
nations = ['United States', 'Canada', 'United Kingdom', 'Italy', 'Australia',
       'France', 'Iceland', 'Germany', 'Switzerland', 'Indonesia','Russia',
           'Brazil','New Zealand','India','Japan','China']
country_table = country_table[country_table.photo_location_country.isin(nations)]
featured_photo = country_table.loc[country_table.groupby(['photo_location_country'])['stats_downloads'].idxmax()]

featured_photo
# Out:
#           photo_id                                photo_url  \
# 7887   tNDvFkxkBHo  https://unsplash.com/photos/tNDvFkxkBHo
# 10712  QTIugFX1Gug  https://unsplash.com/photos/QTIugFX1Gug
# 7585   lpjb_UMOyx8  https://unsplash.com/photos/lpjb_UMOyx8
# 17665  wpTWYBll4_w  https://unsplash.com/photos/wpTWYBll4_w
# 10624  urUdKCxsTUI  https://unsplash.com/photos/urUdKCxsTUI
# 14850  EPy0gBJzzZU  https://unsplash.com/photos/EPy0gBJzzZU
# 2224   c9MFM8rSMsQ  https://unsplash.com/photos/c9MFM8rSMsQ
# 22063  83zRhEhFMfo  https://unsplash.com/photos/83zRhEhFMfo
# 19555  a8lTjWJJgLA  https://unsplash.com/photos/a8lTjWJJgLA
# 15128  ln5drpv_ImI  https://unsplash.com/photos/ln5drpv_ImI
# 10573  fY1ECB1RCd0  https://unsplash.com/photos/fY1ECB1RCd0
# 19041  eOpewngf68w  https://unsplash.com/photos/eOpewngf68w
# 11025  NodtnCsLdTE  https://unsplash.com/photos/NodtnCsLdTE
# 19685  mawU2PoJWfU  https://unsplash.com/photos/mawU2PoJWfU
# 5373   8mqOw4DBBSg  https://unsplash.com/photos/8mqOw4DBBSg
# 5341   oMpAz-DN-9I  https://unsplash.com/photos/oMpAz-DN-9I
#
#       photo_location_country  photo_location_latitude  \
# 7887               Australia                      NaN
# 10712                 Brazil               -23.013488
# 7585                  Canada                51.425385
# 17665                  China                39.904211
# 10624                 France                48.856614
# 14850                Germany                      NaN
# 2224                 Iceland                63.616280
# 22063                  India                17.796949
# 19555              Indonesia                -8.409518
# 15128                  Italy                      NaN
# 10573                  Japan                35.048923
# 19041            New Zealand               -35.684392
# 11025                 Russia                52.723598
# 19685            Switzerland                46.726743
# 5373          United Kingdom                51.311977
# 5341           United States                41.437698
#
#        photo_location_longitude  stats_downloads  \
# 7887                        NaN           228249
# 10712                -43.323730            51768
# 7585                -116.177319           324889
# 17665                116.407395           101617
# 10624                  2.352222           171664
# 14850                       NaN           359925
# 2224                 -20.013557           120209
# 22063                 83.381610           151385
# 19555                115.188916           106599
# 15128                       NaN           410213
# 10573                135.762833           270865
# 19041                174.335767           387671
# 11025                 41.442306           193839
# 19685                  7.967473           259834
# 5373                  -0.476904           459271
# 5341                -112.668859          1590203
#
#                                           ai_description  \
# 7887                             view of seashore sunset
# 10712                        two people surfing on water
# 7585                              photo of two mountains
# 17665                                  yellow jelly fish
# 10624         shallow focus photography of white flowers
# 14850             green tree on grassland during daytime
# 2224                                                 NaN
# 22063   wayfarer sunglasses on beach sand during daytime
# 19555        eagle-eye view photography of brown pathway
# 15128     silhouette photo of mountain during night time
# 10573  shallow focus photography of white-and-pink pe...
# 19041                        blue and brown steel bridge
# 11025    brown Scottish fold in brown thick-pile blanket
# 19685  bird's eye view photography of trees and body ...
# 5373                  top view of green succulent plants
# 5341                    silhouette photography of person
#
#                                        photo_description
# 7887                     Sunset over an Australian Beach
# 10712                                            Surfers
# 7585                               Lake Louise landscape
# 17665                                                NaN
# 10624                   Spring flower blossoms on branch
# 14850                          Tree in green wheat field
# 2224   It’s often hard to see the beauty that’s right...
# 22063                                       At the beach
# 19555                                  A Morning in Bali
# 15128                           Sublime purple night sky
# 10573                                                NaN
# 19041                         Whangarei Falls footbridge
# 11025  Crouching Tiger, Hidden Dragon. Photo of a kit...
# 19685                          Blue lake and green shore
# 5373   From a sunny afternoon spent wandering around ...
# 5341                                                 NaN

# %%
keyword_merge = pd.merge(country_table, keyword_table, on='photo_id', how='inner')
keyword_photo = keyword_merge.loc[keyword_merge.groupby(['photo_location_country','keyword'])['stats_downloads'].idxmax()]
keyword_photo
# Out:
#            photo_id                                photo_url  \
# 40672   swtg-ahmGzY  https://unsplash.com/photos/swtg-ahmGzY
# 252223  XK7thML3zEQ  https://unsplash.com/photos/XK7thML3zEQ
# 16903   iSYYLt2rKac  https://unsplash.com/photos/iSYYLt2rKac
# 130221  tNDvFkxkBHo  https://unsplash.com/photos/tNDvFkxkBHo
# 130220  tNDvFkxkBHo  https://unsplash.com/photos/tNDvFkxkBHo
# 130224  tNDvFkxkBHo  https://unsplash.com/photos/tNDvFkxkBHo
# 160010  1KJAjCSyi48  https://unsplash.com/photos/1KJAjCSyi48
# 323198  LZMc0dJGRUA  https://unsplash.com/photos/LZMc0dJGRUA
# 177204  QTIugFX1Gug  https://unsplash.com/photos/QTIugFX1Gug
# 174870  QTIugFX1Gug  https://unsplash.com/photos/QTIugFX1Gug
# 345316  9BK7Yae7tTY  https://unsplash.com/photos/9BK7Yae7tTY
# 98169   CQl3Y5bV6FA  https://unsplash.com/photos/CQl3Y5bV6FA
# 112584  lpjb_UMOyx8  https://unsplash.com/photos/lpjb_UMOyx8
# 100003  lpjb_UMOyx8  https://unsplash.com/photos/lpjb_UMOyx8
# 100004  lpjb_UMOyx8  https://unsplash.com/photos/lpjb_UMOyx8
# 236180  e3dY8laAQtA  https://unsplash.com/photos/e3dY8laAQtA
# 107640  lpjb_UMOyx8  https://unsplash.com/photos/lpjb_UMOyx8
# 35258   StV72L0DH4A  https://unsplash.com/photos/StV72L0DH4A
# 197289  I4ScSrKsfIg  https://unsplash.com/photos/I4ScSrKsfIg
# 124555  An18-liwqIw  https://unsplash.com/photos/An18-liwqIw
# 317801  ACt8ycSzpdE  https://unsplash.com/photos/ACt8ycSzpdE
# 258891  i-vgADdh6E4  https://unsplash.com/photos/i-vgADdh6E4
# 170512  urUdKCxsTUI  https://unsplash.com/photos/urUdKCxsTUI
# 98307   x8xJpClTvR0  https://unsplash.com/photos/x8xJpClTvR0
# 317848  bRDL3HDmoqU  https://unsplash.com/photos/bRDL3HDmoqU
# 8396    ig-lw0Dtz34  https://unsplash.com/photos/ig-lw0Dtz34
# 5173    ig-lw0Dtz34  https://unsplash.com/photos/ig-lw0Dtz34
# 3343    ig-lw0Dtz34  https://unsplash.com/photos/ig-lw0Dtz34
# 34151   MAjtbFMV5_k  https://unsplash.com/photos/MAjtbFMV5_k
# 132489  v4e3JI7DDHI  https://unsplash.com/photos/v4e3JI7DDHI
# ...             ...                                      ...
# 3063    FdoxtIWEwp0  https://unsplash.com/photos/FdoxtIWEwp0
# 264785  eOpewngf68w  https://unsplash.com/photos/eOpewngf68w
# 160056  KonWFWUaAuk  https://unsplash.com/photos/KonWFWUaAuk
# 264680  eOpewngf68w  https://unsplash.com/photos/eOpewngf68w
# 283198  uanoYn1AmPs  https://unsplash.com/photos/uanoYn1AmPs
# 160032  KonWFWUaAuk  https://unsplash.com/photos/KonWFWUaAuk
# 216664  NXKqkXzchPQ  https://unsplash.com/photos/NXKqkXzchPQ
# 356552  AAjtt5UwlTs  https://unsplash.com/photos/AAjtt5UwlTs
# 205921  q-DJ9XhKkhA  https://unsplash.com/photos/q-DJ9XhKkhA
# 158574  IpIenETtzXM  https://unsplash.com/photos/IpIenETtzXM
# 204040  q-DJ9XhKkhA  https://unsplash.com/photos/q-DJ9XhKkhA
# 33340   VYv2cfReifM  https://unsplash.com/photos/VYv2cfReifM
# 242798  jl2T_E4tUyo  https://unsplash.com/photos/jl2T_E4tUyo
# 302616  mawU2PoJWfU  https://unsplash.com/photos/mawU2PoJWfU
# 302156  mawU2PoJWfU  https://unsplash.com/photos/mawU2PoJWfU
# 302121  mawU2PoJWfU  https://unsplash.com/photos/mawU2PoJWfU
# 302997  mawU2PoJWfU  https://unsplash.com/photos/mawU2PoJWfU
# 305556  mawU2PoJWfU  https://unsplash.com/photos/mawU2PoJWfU
# 73430   8mqOw4DBBSg  https://unsplash.com/photos/8mqOw4DBBSg
# 73520   8mqOw4DBBSg  https://unsplash.com/photos/8mqOw4DBBSg
# 243111  8mY3XGmmTUo  https://unsplash.com/photos/8mY3XGmmTUo
# 73449   8mqOw4DBBSg  https://unsplash.com/photos/8mqOw4DBBSg
# 56874   a5uptAdUmjE  https://unsplash.com/photos/a5uptAdUmjE
# 197312  __U6tHlaapI  https://unsplash.com/photos/__U6tHlaapI
# 160013  YCh5-MpB6C8  https://unsplash.com/photos/YCh5-MpB6C8
# 73333   oMpAz-DN-9I  https://unsplash.com/photos/oMpAz-DN-9I
# 73327   oMpAz-DN-9I  https://unsplash.com/photos/oMpAz-DN-9I
# 73294   oMpAz-DN-9I  https://unsplash.com/photos/oMpAz-DN-9I
# 83327   E4944K_4SvI  https://unsplash.com/photos/E4944K_4SvI
# 73302   oMpAz-DN-9I  https://unsplash.com/photos/oMpAz-DN-9I
#
#        photo_location_country  photo_location_latitude  \
# 40672               Australia                      NaN
# 252223              Australia               -25.274398
# 16903               Australia               -32.796609
# 130221              Australia                      NaN
# 130220              Australia                      NaN
# 130224              Australia                      NaN
# 160010                 Brazil               -20.812711
# 323198                 Brazil               -25.304952
# 177204                 Brazil               -23.013488
# 174870                 Brazil               -23.013488
# 345316                 Brazil               -22.330469
# 98169                  Canada                46.510712
# 112584                 Canada                51.425385
# 100003                 Canada                51.425385
# 100004                 Canada                51.425385
# 236180                 Canada                43.642454
# 107640                 Canada                51.425385
# 35258                   China                22.543096
# 197289                  China                30.554201
# 124555                  China                42.951303
# 317801                  China                39.921469
# 258891                  China                39.904211
# 170512                 France                48.856614
# 98307                  France                49.551327
# 317848                 France                45.873625
# 8396                   France                46.602496
# 5173                   France                46.602496
# 3343                   France                46.602496
# 34151                 Germany                53.582997
# 132489                Germany                51.985565
# ...                       ...                      ...
# 3063              New Zealand               -36.860240
# 264785            New Zealand               -35.684392
# 160056            New Zealand               -44.698338
# 264680            New Zealand               -35.684392
# 283198            New Zealand               -36.836406
# 160032            New Zealand               -44.698338
# 216664                 Russia                52.010272
# 356552                 Russia                60.163333
# 205921                 Russia                59.934280
# 158574                 Russia                59.934280
# 204040                 Russia                59.934280
# 33340                  Russia                      NaN
# 242798            Switzerland                46.742226
# 302616            Switzerland                46.726743
# 302156            Switzerland                46.726743
# 302121            Switzerland                46.726743
# 302997            Switzerland                46.726743
# 305556            Switzerland                46.726743
# 73430          United Kingdom                51.311977
# 73520          United Kingdom                51.311977
# 243111         United Kingdom                54.179432
# 73449          United Kingdom                51.311977
# 56874          United Kingdom                51.459778
# 197312         United Kingdom                50.053534
# 160013          United States                39.742078
# 73333           United States                41.437698
# 73327           United States                41.437698
# 73294           United States                41.437698
# 83327           United States                19.354803
# 73302           United States                41.437698
#
#         photo_location_longitude  stats_downloads  \
# 40672                        NaN             9536
# 252223                133.775136           189916
# 16903                 134.198539            49462
# 130221                       NaN           228249
# 130220                       NaN           228249
# 130224                       NaN           228249
# 160010                -49.376521            21430
# 323198                -49.054143             4464
# 177204                -43.323730            51768
# 174870                -43.323730            51768
# 345316                -42.569538            11616
# 98169                 -63.416814            97440
# 112584               -116.177319           324889
# 100003               -116.177319           324889
# 100004               -116.177319           324889
# 236180                -79.386123           131248
# 107640               -116.177319           324889
# 35258                 114.057865             2622
# 197289                114.387624            19991
# 124555                 89.189752             3137
# 317801                116.443107            72801
# 258891                116.407395            20655
# 170512                  2.352222           171664
# 98307                   3.642592            15542
# 317848                  6.686892            46783
# 8396                   -1.853310           149496
# 5173                   -1.853310           149496
# 3343                   -1.853310           149496
# 34151                  10.101052           104498
# 132489                  9.252091            96089
# ...                          ...              ...
# 3063                  174.774093            14709
# 264785                174.335767           387671
# 160056                169.116328            70560
# 264680                174.335767           387671
# 283198                174.424488            96291
# 160032                169.116328            70560
# 216664                106.169219            50720
# 356552                 29.154444             2086
# 205921                 30.335099            30821
# 158574                 30.335099            18043
# 204040                 30.335099            30821
# 33340                        NaN             4588
# 242798                  7.928609            72084
# 302616                  7.967473           259834
# 302156                  7.967473           259834
# 302121                  7.967473           259834
# 302997                  7.967473           259834
# 305556                  7.967473           259834
# 73430                  -0.476904           459271
# 73520                  -0.476904           459271
# 243111                 -6.058722            13074
# 73449                  -0.476904           459271
# 56874                  -2.589575            78227
# 197312                 -5.692260           216059
# 160013                -75.098825           176157
# 73333                -112.668859          1590203
# 73327                -112.668859          1590203
# 73294                -112.668859          1590203
# 83327                -154.979510           482857
# 73302                -112.668859          1590203
#
#                                            ai_description  \
# 40672                           bee in fornt of Sunflower
# 252223                     aerial photography of sea wave
# 16903                             galaxy during nighttime
# 130221                            view of seashore sunset
# 130220                            view of seashore sunset
# 130224                            view of seashore sunset
# 160010                yellow sunflower in tilt shift lens
# 323198               silhouette of mountain during sunset
# 177204                        two people surfing on water
# 174870                        two people surfing on water
# 345316             silhouette of mountains under calm sky
# 98169                         brown animal on green grass
# 112584                             photo of two mountains
# 100003                             photo of two mountains
# 100004                             photo of two mountains
# 236180                          photography of sea corals
# 107640                             photo of two mountains
# 35258                        pink and green flower petals
# 197289  swamp surrounded with green pine trees during ...
# 124555                                                NaN
# 317801             white concrete building during daytime
# 258891                          silhouette photo of plant
# 170512         shallow focus photography of white flowers
# 98307               brown grass surrounded by green trees
# 317848                              snow covered mountain
# 8396            time lapsed photography of cumulus clouds
# 5173            time lapsed photography of cumulus clouds
# 3343            time lapsed photography of cumulus clouds
# 34151                              yellow and brown roses
# 132489                 empty road between trees on forest
# ...                                                   ...
# 3063    selective focus photography of red petaled flo...
# 264785                        blue and brown steel bridge
# 160056               tree on body of water near mountains
# 264680                        blue and brown steel bridge
# 283198                                  ocean tunnel wave
# 160032               tree on body of water near mountains
# 216664                                        pebbles lot
# 356552  woman in black dress standing on forest during...
# 205921          landscape photography of waves and clouds
# 158574                      pink tulips blooms at daytime
# 204040          landscape photography of waves and clouds
# 33340                 under cloudy sky during golden hour
# 242798      aerial view photography of mountain with snow
# 302616  bird's eye view photography of trees and body ...
# 302156  bird's eye view photography of trees and body ...
# 302121  bird's eye view photography of trees and body ...
# 302997  bird's eye view photography of trees and body ...
# 305556  bird's eye view photography of trees and body ...
# 73430                  top view of green succulent plants
# 73520                  top view of green succulent plants
# 243111              stones on seashore under starry night
# 73449                  top view of green succulent plants
# 56874                                  seawaves wallpaper
# 197312           three person looking stars and milky way
# 160013             gray and white bird perching on branch
# 73333                    silhouette photography of person
# 73327                    silhouette photography of person
# 73294                    silhouette photography of person
# 83327                              lava dripping to ocean
# 73302                    silhouette photography of person
#
#                                         photo_description   keyword
# 40672   Bees work very hard and do a fantastic job of ...    flower
# 252223                                 Black sand beaches    forest
# 16903   absolutely zero light pollution.  More on Inst...  mountain
# 130221                    Sunset over an Australian Beach    nature
# 130220                    Sunset over an Australian Beach       sea
# 130224                    Sunset over an Australian Beach       sky
# 160010                                          sunflower    flower
# 323198                                                sky  mountain
# 177204                                            Surfers    nature
# 174870                                            Surfers       sea
# 345316                               Pôr do sol no Chapéu       sky
# 98169                                    Curious Stranger    flower
# 112584                              Lake Louise landscape    forest
# 100003                              Lake Louise landscape  mountain
# 100004                              Lake Louise landscape    nature
# 236180                                                NaN       sea
# 107640                              Lake Louise landscape       sky
# 35258                                           Pink lady    flower
# 197289                                                NaN    forest
# 124555  The Turpan Depression, nestled at the foot of ...  mountain
# 317801                                                NaN    nature
# 258891                             Beijing Horizon sunset       sky
# 170512                   Spring flower blossoms on branch    flower
# 98307                                       Mystic Autumn    forest
# 317848  My mountain.  Please go like this pic on my In...  mountain
# 8396                          Sand coastline on clear day    nature
# 5173                          Sand coastline on clear day       sea
# 3343                          Sand coastline on clear day       sky
# 34151                          Top view of a rose pattern    flower
# 132489                                                NaN    forest
# ...                                                   ...       ...
# 3063                      Deep red chrysanthemum up close    flower
# 264785                         Whangarei Falls footbridge    forest
# 160056                                                NaN  mountain
# 264680                         Whangarei Falls footbridge    nature
# 283198                         Splashing wave from within       sea
# 160032                                                NaN       sky
# 216664                            Beach rocks and pebbles    flower
# 356552                                                NaN    forest
# 205921                                                NaN  mountain
# 158574                                      Sunlit tulips    nature
# 204040                                                NaN       sea
# 33340                                                 NaN       sky
# 242798  A few days ago, i drove to the alps with some ...    flower
# 302616                          Blue lake and green shore    forest
# 302156                          Blue lake and green shore  mountain
# 302121                          Blue lake and green shore    nature
# 302997                          Blue lake and green shore       sea
# 305556                          Blue lake and green shore       sky
# 73430   From a sunny afternoon spent wandering around ...    flower
# 73520   From a sunny afternoon spent wandering around ...    forest
# 243111                           Stars over a rocky beach  mountain
# 73449   From a sunny afternoon spent wandering around ...    nature
# 56874                                                 NaN       sea
# 197312  We are so small compared to the inconceivably ...       sky
# 160013  A Blue-gray Gnatcatcher sits perched in a beau...    flower
# 73333                                                 NaN    forest
# 73327                                                 NaN  mountain
# 73294                                                 NaN    nature
# 83327   I was visiting the Big Island of Hawaii with s...       sea
# 73302                                                 NaN       sky
#
# [91 rows x 9 columns]

# %% [markdown]
# ## Table combination

# %% [markdown]
# Develop a new table combining the color, keyword, camera and nation features with photo id for further filtering process.

# %%
color_table = datasets['colors'][['photo_id','keyword']]
color_table = color_table.rename(columns={"photo_id": "photo_id", "keyword": "color"})

keyword_table = datasets['conversions'][['photo_id','keyword']]

camera_table = datasets['photos'][['photo_id','exif_camera_make','photo_location_country']]
camera_table['exif_camera_make'] = camera_name
# Out:
# C:\Users\Public\anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
newkeyword = keyword_table.replace({'keyword':'natural'},{'keyword':'nature'}, regex=True)
newkeyword = newkeyword.replace({'keyword':'flowers'},{'keyword':'flower'}, regex=True)
newkeyword = newkeyword.replace({'keyword':'ocean'},{'keyword':'sea'}, regex=True)

keyword_table = newkeyword[newkeyword.keyword.isin(['nature', 'flower', 'mountain', 'sea', 'sky', 'forest'])]

# %%
newcountry = camera_table.dropna(subset = ['photo_location_country'])
newcountry = newcountry.replace({'photo_location_country':'USA'},{'photo_location_country':'United States'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'美國'},{'photo_location_country':'United States'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Deutschland'},{'photo_location_country':'Germany'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Schweiz'},{'photo_location_country':'Switzerland'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Italien'},{'photo_location_country':'Italy'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Italia'},{'photo_location_country':'Italy'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Россия'},{'photo_location_country':'Russia'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Brasil'},{'photo_location_country':'Brazil'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'中国'},{'photo_location_country':'China'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Österreich'},{'photo_location_country':'Austria'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'México'},{'photo_location_country':'Mexico'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Latvija'},{'photo_location_country':'Latvia'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'España'},{'photo_location_country':'Spain'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'Nederland'},{'photo_location_country':'Netherlands'}, regex=True)
newcountry = newcountry.replace({'photo_location_country':'日本'},{'photo_location_country':'Japan'}, regex=True)

camera_table = newcountry
country_name_file = Counter(country_name.flat).most_common(50)
test = np.array(country_name_file)
top_country_file = Counter(test.flat)
test[:,0]
# Out:
# array(['United States', 'Canada', 'Italy', 'United Kingdom', 'Germany',
#        'Australia', 'France', 'Iceland', 'Switzerland', 'Austria',
#        'Indonesia', 'Spain', 'Brazil', 'Russia', 'New Zealand',
#        'Portugal', 'Mexico', 'Netherlands', 'India', 'Norway',
#        'South Africa', 'Japan', 'China', 'Latvia', 'Maldives', 'Romania',
#        'Greece', 'Iran', 'Poland', 'Sweden', 'Vietnam', 'Thailand',
#        'Chile', 'Denmark', 'Ukraine', 'Argentina', 'Turkey', 'Hungary',
#        'Singapore', 'Philippines', 'Slovenia', 'Belgium', 'Costa Rica',
#        'Croatia', 'Hong Kong', 'Ireland', 'Finland', 'Taiwan', 'Morocco',
#        'Slovakia'], dtype='<U14')

# %%
camera_table = camera_table[camera_table.photo_location_country.isin(['United States', 
       'Canada', 'Italy', 'United Kingdom', 'Germany',
       'Australia', 'France', 'Iceland', 'Switzerland', 'Austria',
       'Indonesia', 'Spain', 'Brazil', 'Russia', 'New Zealand',
       'Portugal', 'Mexico', 'Netherlands', 'India', 'Norway',
       'South Africa', 'Japan', 'China', 'Latvia', 'Maldives', 'Romania',
       'Greece', 'Iran', 'Poland', 'Sweden', 'Vietnam', 'Thailand',
       'Chile', 'Denmark', 'Ukraine', 'Argentina', 'Turkey', 'Hungary',
       'Singapore', 'Philippines', 'Slovenia', 'Belgium', 'Costa Rica',
       'Croatia', 'Hong Kong', 'Ireland', 'Finland', 'Taiwan', 'Morocco',
       'Slovakia'])]

# %% [markdown]
# # Prediction modelling

# %% [markdown]
# Count the total images number of each nation

# %%
top_colors = ['darkslategray','dimgray','darkolivegreen','black','gray','darkgray']
top_keywords = ['nature', 'flower', 'mountain', 'sea', 'sky', 'forest']
top_cameras = ['canon', 'nikon', 'sony']
infotable = pd.DataFrame()
for col in top_colors:
    for kw in top_keywords:
        for cmr in top_cameras:
            num_photo_1 = color_table[color_table.color.isin([col])]
            num_photo_2 = keyword_table[keyword_table.keyword.isin([kw])]
            num_photo_3 = camera_table[camera_table.exif_camera_make.isin([cmr])]
            combinedata = pd.merge(num_photo_1, num_photo_2, on='photo_id', how='inner')
            combinedata = pd.merge(combinedata, num_photo_3, on='photo_id', how='inner')
            num_photo_4 = combinedata.drop_duplicates(subset=['photo_id'])
            num_photo_5 = num_photo_4[['photo_location_country']].to_numpy().flat
            num_photo_6 = Counter(num_photo_5).most_common(6)
            top_country_name = np.array(num_photo_6)[:,0]
            top_country_number = np.array(num_photo_6)[:,1]
            information = pd.DataFrame({"color": [col], "keyword": [kw], "camera":[cmr],
                                      "Nation1":[top_country_name[0]], "Num1":[top_country_number[0]],
                                      "Nation2":[top_country_name[1]], "Num2":[top_country_number[1]],
                                      "Nation3":[top_country_name[2]], "Num3":[top_country_number[2]],
                                      "Nation4":[top_country_name[3]], "Num4":[top_country_number[3]],
                                      "Nation5":[top_country_name[4]], "Num5":[top_country_number[4]]})
            infotable = infotable.append(information, ignore_index=True)

# %%
df = pd.DataFrame.from_dict(top_country_file, orient='index').reset_index()
first_nation = df.rename(columns={'index':'Nation1', 0:'count1'})
first_nation = infotable.merge(first_nation, on='Nation1', how='left')

first_nation['nation1ratio'] = first_nation['Num1'].astype(float)/first_nation['count1']
infotable_update = infotable
infotable_update['nation1ratio'] = first_nation['nation1ratio']

second_nation = df.rename(columns={'index':'Nation2', 0:'count2'})
second_nation = infotable.merge(second_nation, on='Nation2', how='left')
second_nation['nation2ratio'] = second_nation['Num2'].astype(int)/second_nation['count2']
infotable_update['nation2ratio'] = second_nation['nation2ratio']

third_nation = df.rename(columns={'index':'Nation3', 0:'count3'})
third_nation = infotable.merge(third_nation, on='Nation3', how='left')
third_nation['nation3ratio'] = third_nation['Num3'].astype(int)/third_nation['count3']
infotable_update['nation3ratio'] = third_nation['nation3ratio']

fourth_nation = df.rename(columns={'index':'Nation4', 0:'count4'})
fourth_nation = infotable.merge(fourth_nation, on='Nation4', how='left')
fourth_nation['nation4ratio'] = fourth_nation['Num4'].astype(int)/fourth_nation['count4']
infotable_update['nation4ratio'] = fourth_nation['nation4ratio']

fifth_nation = df.rename(columns={'index':'Nation5', 0:'count5'})
fifth_nation = infotable.merge(fifth_nation, on='Nation5', how='left')
fifth_nation['nation5ratio'] = fifth_nation['Num5'].astype(int)/fifth_nation['count5']
infotable_update['nation5ratio'] = fifth_nation['nation5ratio']

infotable_update['sum'] = infotable_update['nation1ratio'] + infotable_update['nation2ratio'] + infotable_update['nation3ratio']

infotable_update['sum'] = infotable_update['sum'] + infotable_update['nation4ratio'] + infotable_update['nation5ratio']
infotable_update['nation1ratio'] = infotable_update['nation1ratio']/infotable_update['sum'] 
infotable_update['nation2ratio'] = infotable_update['nation2ratio']/infotable_update['sum'] 
infotable_update['nation3ratio'] = infotable_update['nation3ratio']/infotable_update['sum'] 
infotable_update['nation4ratio'] = infotable_update['nation4ratio']/infotable_update['sum'] 
infotable_update['nation5ratio'] = infotable_update['nation5ratio']/infotable_update['sum']

# %%
infotable_update
# In this table, each nation#ratio represents the percentage of possiblity that the taste of correponding color, 
# keyword and camera are more likely to from the corresponding nation#. It is calculated by 
# 1) the image amount of that nation with selected features, divided by the total image amount of that nation.
# 2) calculate the sum of all ratios
# 3) the percentage of each ratio occupied the sum value
# Out:
#              color   keyword camera        Nation1 Num1         Nation2 Num2  \
# 0    darkslategray    nature  canon  United States   64           Italy   32
# 1    darkslategray    nature  nikon  United States   48           Italy   12
# 2    darkslategray    nature   sony  United States   33         Iceland   15
# 3    darkslategray    flower  canon  United States   15         Germany    7
# 4    darkslategray    flower  nikon  United States   11     Netherlands    4
# 5    darkslategray    flower   sony  United States    7         Austria    2
# 6    darkslategray  mountain  canon          Italy   29   United States   17
# 7    darkslategray  mountain  nikon  United States   15           Italy   11
# 8    darkslategray  mountain   sony  United States   13         Iceland    4
# 9    darkslategray       sea  canon  United States   21     New Zealand   12
# 10   darkslategray       sea  nikon  United States   13       Australia    6
# 11   darkslategray       sea   sony  United States   11       Australia    6
# 12   darkslategray       sky  canon  United States   29          France    4
# 13   darkslategray       sky  nikon  United States   31          Brazil    4
# 14   darkslategray       sky   sony  United States    5         Iceland    4
# 15   darkslategray    forest  canon  United States   31           Italy   12
# 16   darkslategray    forest  nikon  United States   17  United Kingdom    3
# 17   darkslategray    forest   sony  United States   10         Germany    5
# 18         dimgray    nature  canon  United States   51           Italy   23
# 19         dimgray    nature  nikon  United States   32           Italy    8
# 20         dimgray    nature   sony  United States   22         Iceland   10
# 21         dimgray    flower  canon  United States   15         Germany    6
# 22         dimgray    flower  nikon  United States   11  United Kingdom    3
# 23         dimgray    flower   sony  United States    5     New Zealand    2
# 24         dimgray  mountain  canon          Italy   24   United States   15
# 25         dimgray  mountain  nikon  United States    9           Italy    8
# 26         dimgray  mountain   sony  United States    8         Iceland    4
# 27         dimgray       sea  canon  United States   10       Australia    5
# 28         dimgray       sea  nikon  United States   11  United Kingdom    3
# 29         dimgray       sea   sony  United States    6       Australia    4
# ..             ...       ...    ...            ...  ...             ...  ...
# 78            gray  mountain  canon          Italy   31   United States   12
# 79            gray  mountain  nikon          Italy    9   United States    8
# 80            gray  mountain   sony  United States    4           Italy    3
# 81            gray       sea  canon  United States   13       Australia    3
# 82            gray       sea  nikon  United States    9  United Kingdom    3
# 83            gray       sea   sony         Canada    3   United States    3
# 84            gray       sky  canon  United States   14          France    3
# 85            gray       sky  nikon  United States   13            Iran    2
# 86            gray       sky   sony         Canada    2           Spain    2
# 87            gray    forest  canon  United States   17           Italy   12
# 88            gray    forest  nikon  United States    6          Canada    3
# 89            gray    forest   sony  United States    4         Germany    4
# 90        darkgray    nature  canon  United States   43           Italy   32
# 91        darkgray    nature  nikon  United States   31  United Kingdom    6
# 92        darkgray    nature   sony  United States   18         Iceland    9
# 93        darkgray    flower  canon  United States   10         Germany    4
# 94        darkgray    flower  nikon  United States   10  United Kingdom    3
# 95        darkgray    flower   sony  United States    3         Romania    1
# 96        darkgray  mountain  canon          Italy   28   United States   11
# 97        darkgray  mountain  nikon  United States    8           Italy    6
# 98        darkgray  mountain   sony        Iceland    5         Germany    4
# 99        darkgray       sea  canon  United States   14     New Zealand   11
# 100       darkgray       sea  nikon  United States   14       Australia    5
# 101       darkgray       sea   sony  United States    9       Australia    3
# 102       darkgray       sky  canon  United States   13           Italy    5
# 103       darkgray       sky  nikon  United States   12          Brazil    2
# 104       darkgray       sky   sony  United States    4         Austria    2
# 105       darkgray    forest  canon  United States   19           Italy   12
# 106       darkgray    forest  nikon  United States    8          Canada    3
# 107       darkgray    forest   sony  United States    5         Germany    3
#
#             Nation3 Num3         Nation4 Num4         Nation5 Num5  \
# 0            Canada   14     Switzerland    8         Austria    8
# 1         Australia   10         Iceland    8          Canada    7
# 2            Canada   12         Germany   10           Italy   10
# 3            Taiwan    5  United Kingdom    4          Russia    3
# 4           Romania    3            Iran    2          France    2
# 5             Italy    2     New Zealand    1           China    1
# 6       Switzerland   10         Austria    9          Canada    8
# 7       New Zealand    6          France    5          Norway    2
# 8           Germany    4     Switzerland    4           Italy    4
# 9         Australia    4    South Africa    4  United Kingdom    3
# 10          Iceland    4  United Kingdom    3     New Zealand    3
# 11      New Zealand    5          Canada    5          Norway    2
# 12          Germany    3          Canada    3     Switzerland    3
# 13            Italy    4       Australia    3          Russia    3
# 14            Spain    3          Canada    2         Austria    2
# 15          Austria    6          Canada    5         Germany    5
# 16           Canada    2         Germany    2           Spain    2
# 17      Switzerland    3           Italy    3         Iceland    2
# 18           Canada   12     Switzerland    9         Austria    7
# 19        Australia    8  United Kingdom    6         Iceland    5
# 20          Germany    9          Canada    9          France    5
# 21   United Kingdom    3           India    3          Taiwan    3
# 22      Netherlands    3          France    2          Canada    2
# 23          Romania    1           Japan    1          Canada    1
# 24          Austria    8     Switzerland    7          Canada    6
# 25      New Zealand    4     Switzerland    3          Canada    2
# 26          Germany    4     Switzerland    3           Italy    2
# 27      New Zealand    3  United Kingdom    2          France    2
# 28          Iceland    3       Australia    2         Romania    1
# 29           Canada    2     New Zealand    2          Norway    1
# ..              ...  ...             ...  ...             ...  ...
# 78      Switzerland    8         Iceland    2          Canada    2
# 79           Canada    2     New Zealand    2     Switzerland    1
# 80      Switzerland    2         Iceland    2         Germany    1
# 81   United Kingdom    2     New Zealand    2     Switzerland    2
# 82           Russia    2       Australia    2           Italy    2
# 83        Australia    2          Mexico    1  United Kingdom    1
# 84           Canada    2          Russia    1     Philippines    1
# 85           Canada    2        Thailand    2          Brazil    2
# 86   United Kingdom    2   United States    2          France    1
# 87          Austria    3     Switzerland    3      Costa Rica    2
# 88   United Kingdom    3     New Zealand    2         Germany    1
# 89      Switzerland    3         Iceland    1  United Kingdom    1
# 90           Canada   10         Austria    8         Iceland    7
# 91          Iceland    5       Australia    5     Switzerland    4
# 92           Canada    9         Germany    7           Italy    5
# 93           Russia    2           Italy    2     Netherlands    2
# 94          Romania    2         Germany    1         Ukraine    1
# 95          Belgium    1       Argentina    1         Iceland    1
# 96      Switzerland    9          Canada    9         Austria    5
# 97      New Zealand    3          France    2     Switzerland    2
# 98            Italy    4     Switzerland    3   United States    3
# 99        Australia    5          France    5    South Africa    4
# 100  United Kingdom    4          Greece    3          Russia    2
# 101          Norway    2  United Kingdom    2        Slovenia    1
# 102     Switzerland    3          France    3          Canada    2
# 103       Argentina    2        Thailand    1           Spain    1
# 104         Finland    1       Australia    1          France    1
# 105         Austria    4         Germany    4      Costa Rica    2
# 106  United Kingdom    3     New Zealand    2         Germany    1
# 107     Switzerland    2  United Kingdom    1           Italy    1
#
#      nation1ratio  nation2ratio  nation3ratio  nation4ratio  nation5ratio  \
# 0        0.126144      0.351463      0.150254      0.153496      0.218643
# 1        0.163050      0.227147      0.237583      0.242743      0.129477
# 2        0.094021      0.381751      0.186169      0.179292      0.158766
# 3        0.021922      0.064379      0.792196      0.032884      0.088619
# 4        0.030827      0.314536      0.351784      0.257073      0.045780
# 5        0.067396      0.267007      0.107302      0.205024      0.353271
# 6        0.363715      0.038262      0.219099      0.280880      0.098044
# 7        0.048622      0.198690      0.414154      0.132378      0.206156
# 8        0.096203      0.264414      0.186276      0.288157      0.164950
# 9        0.046267      0.562994      0.061638      0.291923      0.037179
# 10       0.075822      0.244758      0.208396      0.098423      0.372601
# 11       0.043954      0.167682      0.425444      0.108789      0.254132
# 12       0.229995      0.259111      0.149724      0.129556      0.231614
# 13       0.144135      0.372743      0.103637      0.097558      0.281927
# 14       0.036605      0.261582      0.419054      0.079729      0.203030
# 15       0.129297      0.278904      0.347008      0.113557      0.131234
# 16       0.177990      0.176681      0.114022      0.131773      0.399534
# 17       0.095011      0.298946      0.277471      0.158833      0.169739
# 18       0.118830      0.298627      0.152248      0.204137      0.226159
# 19       0.151698      0.211332      0.265249      0.159994      0.211727
# 20       0.085335      0.346483      0.219683      0.190091      0.158409
# 21       0.030596      0.077015      0.034421      0.194591      0.663378
# 22       0.078979      0.121161      0.604380      0.117288      0.078192
# 23       0.038322      0.326421      0.320694      0.272829      0.041734
# 24       0.370998      0.041611      0.307727      0.189032      0.090632
# 25       0.050321      0.249253      0.476250      0.163286      0.060890
# 26       0.073226      0.327049      0.230401      0.267312      0.102012
# 27       0.073292      0.256308      0.468219      0.082454      0.119727
# 28       0.099545      0.152711      0.242507      0.126587      0.378651
# 29       0.050312      0.234592      0.091319      0.357124      0.266653
# ..            ...           ...           ...           ...           ...
# 78       0.592856      0.041184      0.267273      0.061313      0.037375
# 79       0.413227      0.065916      0.089732      0.350915      0.080209
# 80       0.062165      0.259808      0.302579      0.277648      0.097799
# 81       0.121166      0.195565      0.104855      0.396951      0.181463
# 82       0.098434      0.184564      0.442119      0.152991      0.121893
# 83       0.249593      0.045837      0.213728      0.404896      0.085945
# 84       0.084846      0.148500      0.066000      0.122492      0.578162
# 85       0.043297      0.305514      0.036271      0.481416      0.133502
# 86       0.154544      0.541521      0.159646      0.028382      0.115908
# 87       0.046953      0.184689      0.114894      0.080660      0.572804
# 88       0.068110      0.185436      0.191559      0.483459      0.071435
# 89       0.054845      0.345131      0.400422      0.122476      0.077125
# 90       0.095720      0.396943      0.121212      0.246935      0.139190
# 91       0.169101      0.184102      0.243631      0.190761      0.212406
# 92       0.082075      0.366570      0.223457      0.200856      0.127043
# 93       0.070000      0.176200      0.282965      0.078014      0.392822
# 94       0.050929      0.085943      0.426195      0.032049      0.404885
# 95       0.012588      0.175565      0.416967      0.357400      0.037480
# 96       0.418330      0.029492      0.234899      0.131393      0.185886
# 97       0.056688      0.236917      0.452681      0.115754      0.137960
# 98       0.359234      0.202460      0.179281      0.234895      0.024130
# 99       0.030665      0.513067      0.076598      0.089451      0.290220
# 100      0.056114      0.140168      0.090184      0.551508      0.162025
# 101      0.044948      0.104790      0.317631      0.056185      0.476446
# 102      0.123269      0.264196      0.276921      0.232348      0.103266
# 103      0.038242      0.127740      0.542895      0.230319      0.060804
# 104      0.025756      0.178570      0.698046      0.045035      0.052593
# 105      0.050816      0.178844      0.148343      0.067322      0.554675
# 106      0.088797      0.181320      0.187307      0.472727      0.069849
# 107      0.091667      0.346108      0.356939      0.103125      0.102161
#
#           sum
# 0    0.212729
# 1    0.123433
# 2    0.147163
# 3    0.286889
# 4    0.149613
# 5    0.043549
# 6    0.186292
# 7    0.129352
# 8    0.056658
# 9    0.190309
# 10   0.071889
# 11   0.104933
# 12   0.052868
# 13   0.090179
# 14   0.057272
# 15   0.100527
# 16   0.040047
# 17   0.044130
# 18   0.179952
# 19   0.088447
# 20   0.108095
# 21   0.205560
# 22   0.058397
# 23   0.054706
# 24   0.151146
# 25   0.074991
# 26   0.045807
# 27   0.057208
# 28   0.046333
# 29   0.050003
# ..        ...
# 78   0.122171
# 79   0.050887
# 80   0.026979
# 81   0.044986
# 82   0.038336
# 83   0.027442
# 84   0.069185
# 85   0.125891
# 86   0.029546
# 87   0.151809
# 88   0.036936
# 89   0.030580
# 90   0.188356
# 91   0.076865
# 92   0.091955
# 93   0.059898
# 94   0.082328
# 95   0.099928
# 96   0.156385
# 97   0.059171
# 98   0.052129
# 99   0.191426
# 100  0.104608
# 101  0.083955
# 102  0.044218
# 103  0.131570
# 104  0.065117
# 105  0.156770
# 106  0.037775
# 107  0.022870
#
# [108 rows x 19 columns]

# %% [markdown]
# # Photo Recommendation

# %%
top_colors = ['darkslategray','dimgray','darkolivegreen','black','gray','darkgray']
top_keywords = ['nature', 'flower', 'mountain', 'sea', 'sky', 'forest']
top_cameras = ['canon', 'nikon', 'sony']

color_table_1 = color_table[color_table.color.isin(top_colors)]
keyword_table_1 = keyword_table[keyword_table.keyword.isin(top_keywords)]
camera_table_1 = camera_table[camera_table.exif_camera_make.isin(top_cameras)]
combinedata = pd.merge(color_table_1, keyword_table_1, on='photo_id', how='inner')
combinedata = pd.merge(combinedata, camera_table_1, on='photo_id', how='inner')
combinedata = combinedata.drop_duplicates()
#note that after droping duplicates, the remaining photo is not the only one output for the corresponding features.

# %%
url_table = datasets['photos'][['photo_id','photo_url','stats_downloads','ai_description','photo_description']]
combinedata = pd.merge(combinedata, url_table, on='photo_id', how='inner')
combinedata
# Out:
#          photo_id           color   keyword exif_camera_make  \
# 0     LUHnStun6JY  darkolivegreen    nature            canon
# 1     LUHnStun6JY            gray    nature            canon
# 2     LUHnStun6JY   darkslategray    nature            canon
# 3     jJKfRPoy9B0            gray  mountain            canon
# 4     jJKfRPoy9B0            gray    nature            canon
# 5     jJKfRPoy9B0        darkgray  mountain            canon
# 6     jJKfRPoy9B0        darkgray    nature            canon
# 7     jJKfRPoy9B0  darkolivegreen  mountain            canon
# 8     jJKfRPoy9B0  darkolivegreen    nature            canon
# 9     jJKfRPoy9B0         dimgray  mountain            canon
# 10    jJKfRPoy9B0         dimgray    nature            canon
# 11    jJKfRPoy9B0   darkslategray  mountain            canon
# 12    jJKfRPoy9B0   darkslategray    nature            canon
# 13    jJKfRPoy9B0           black  mountain            canon
# 14    jJKfRPoy9B0           black    nature            canon
# 15    YvRTYzkT6Hs   darkslategray       sky            nikon
# 16    YvRTYzkT6Hs           black       sky            nikon
# 17    s59sHQILK2c   darkslategray    forest            canon
# 18    favQn8WgRyk   darkslategray    forest            nikon
# 19    favQn8WgRyk           black    forest            nikon
# 20    favQn8WgRyk            gray    forest            nikon
# 21    favQn8WgRyk         dimgray    forest            nikon
# 22    favQn8WgRyk  darkolivegreen    forest            nikon
# 23    swtg-ahmGzY           black    flower            nikon
# 24    99lR0jrBy00  darkolivegreen    nature            canon
# 25    99lR0jrBy00        darkgray    nature            canon
# 26    99lR0jrBy00         dimgray    nature            canon
# 27    99lR0jrBy00            gray    nature            canon
# 28    99lR0jrBy00   darkslategray    nature            canon
# 29    99lR0jrBy00           black    nature            canon
# ...           ...             ...       ...              ...
# 4796  mBz6QjRZKvc           black    nature             sony
# 4797  0NyjudfOt-8           black       sea            canon
# 4798  0NyjudfOt-8   darkslategray       sea            canon
# 4799  Z9DnCWFV1YM           black    flower            canon
# 4800  Z9DnCWFV1YM   darkslategray    flower            canon
# 4801  Z9DnCWFV1YM        darkgray    flower            canon
# 4802  yKGJrfmQAd4  darkolivegreen    flower            nikon
# 4803  RR76ToIL7Sk           black    flower            canon
# 4804  nSokqhD9e04        darkgray    nature             sony
# 4805  zlTEatdlwOQ        darkgray       sea            nikon
# 4806  CqoSqqHhsuI            gray    flower            nikon
# 4807  DkjPhDCCYvU   darkslategray    nature            canon
# 4808  6vSmbnbR0SE   darkslategray    nature             sony
# 4809  Bcmo7nbuX5Q           black  mountain            canon
# 4810  47urRDhCphA           black    flower            nikon
# 4811  JoKJOi9tdJ0   darkslategray    nature             sony
# 4812  H7g0deWbgqo           black    flower             sony
# 4813  i-vgADdh6E4           black       sky            canon
# 4814  4xv3lqnanYc           black    nature            canon
# 4815  4xv3lqnanYc           black       sea            canon
# 4816  AiO4xyDRv-8   darkslategray    flower            canon
# 4817  sCFKb-7K130         dimgray    nature            nikon
# 4818  sCFKb-7K130         dimgray       sky            nikon
# 4819  _Ft-CKcTQFs   darkslategray    flower            canon
# 4820  _Ft-CKcTQFs   darkslategray    nature            canon
# 4821  _Ft-CKcTQFs           black    flower            canon
# 4822  _Ft-CKcTQFs           black    nature            canon
# 4823  yCoCVp6I4nE   darkslategray    forest            canon
# 4824  yCoCVp6I4nE        darkgray    forest            canon
# 4825  b6pk1dugR7A   darkslategray    flower            nikon
#
#      photo_location_country                                photo_url  \
# 0             United States  https://unsplash.com/photos/LUHnStun6JY
# 1             United States  https://unsplash.com/photos/LUHnStun6JY
# 2             United States  https://unsplash.com/photos/LUHnStun6JY
# 3                     Italy  https://unsplash.com/photos/jJKfRPoy9B0
# 4                     Italy  https://unsplash.com/photos/jJKfRPoy9B0
# 5                     Italy  https://unsplash.com/photos/jJKfRPoy9B0
# 6                     Italy  https://unsplash.com/photos/jJKfRPoy9B0
# 7                     Italy  https://unsplash.com/photos/jJKfRPoy9B0
# 8                     Italy  https://unsplash.com/photos/jJKfRPoy9B0
# 9                     Italy  https://unsplash.com/photos/jJKfRPoy9B0
# 10                    Italy  https://unsplash.com/photos/jJKfRPoy9B0
# 11                    Italy  https://unsplash.com/photos/jJKfRPoy9B0
# 12                    Italy  https://unsplash.com/photos/jJKfRPoy9B0
# 13                    Italy  https://unsplash.com/photos/jJKfRPoy9B0
# 14                    Italy  https://unsplash.com/photos/jJKfRPoy9B0
# 15            United States  https://unsplash.com/photos/YvRTYzkT6Hs
# 16            United States  https://unsplash.com/photos/YvRTYzkT6Hs
# 17                Indonesia  https://unsplash.com/photos/s59sHQILK2c
# 18            United States  https://unsplash.com/photos/favQn8WgRyk
# 19            United States  https://unsplash.com/photos/favQn8WgRyk
# 20            United States  https://unsplash.com/photos/favQn8WgRyk
# 21            United States  https://unsplash.com/photos/favQn8WgRyk
# 22            United States  https://unsplash.com/photos/favQn8WgRyk
# 23                Australia  https://unsplash.com/photos/swtg-ahmGzY
# 24                   Canada  https://unsplash.com/photos/99lR0jrBy00
# 25                   Canada  https://unsplash.com/photos/99lR0jrBy00
# 26                   Canada  https://unsplash.com/photos/99lR0jrBy00
# 27                   Canada  https://unsplash.com/photos/99lR0jrBy00
# 28                   Canada  https://unsplash.com/photos/99lR0jrBy00
# 29                   Canada  https://unsplash.com/photos/99lR0jrBy00
# ...                     ...                                      ...
# 4796            Switzerland  https://unsplash.com/photos/mBz6QjRZKvc
# 4797          United States  https://unsplash.com/photos/0NyjudfOt-8
# 4798          United States  https://unsplash.com/photos/0NyjudfOt-8
# 4799          United States  https://unsplash.com/photos/Z9DnCWFV1YM
# 4800          United States  https://unsplash.com/photos/Z9DnCWFV1YM
# 4801          United States  https://unsplash.com/photos/Z9DnCWFV1YM
# 4802         United Kingdom  https://unsplash.com/photos/yKGJrfmQAd4
# 4803                Germany  https://unsplash.com/photos/RR76ToIL7Sk
# 4804                 Canada  https://unsplash.com/photos/nSokqhD9e04
# 4805          United States  https://unsplash.com/photos/zlTEatdlwOQ
# 4806                Germany  https://unsplash.com/photos/CqoSqqHhsuI
# 4807          United States  https://unsplash.com/photos/DkjPhDCCYvU
# 4808                Iceland  https://unsplash.com/photos/6vSmbnbR0SE
# 4809                 Canada  https://unsplash.com/photos/Bcmo7nbuX5Q
# 4810                 Mexico  https://unsplash.com/photos/47urRDhCphA
# 4811          United States  https://unsplash.com/photos/JoKJOi9tdJ0
# 4812                Denmark  https://unsplash.com/photos/H7g0deWbgqo
# 4813                  China  https://unsplash.com/photos/i-vgADdh6E4
# 4814          United States  https://unsplash.com/photos/4xv3lqnanYc
# 4815          United States  https://unsplash.com/photos/4xv3lqnanYc
# 4816                Morocco  https://unsplash.com/photos/AiO4xyDRv-8
# 4817                 Poland  https://unsplash.com/photos/sCFKb-7K130
# 4818                 Poland  https://unsplash.com/photos/sCFKb-7K130
# 4819             Costa Rica  https://unsplash.com/photos/_Ft-CKcTQFs
# 4820             Costa Rica  https://unsplash.com/photos/_Ft-CKcTQFs
# 4821             Costa Rica  https://unsplash.com/photos/_Ft-CKcTQFs
# 4822             Costa Rica  https://unsplash.com/photos/_Ft-CKcTQFs
# 4823                Austria  https://unsplash.com/photos/yCoCVp6I4nE
# 4824                Austria  https://unsplash.com/photos/yCoCVp6I4nE
# 4825                 France  https://unsplash.com/photos/b6pk1dugR7A
#
#       stats_downloads                                     ai_description  \
# 0                1734                    person wearing camouflage pants
# 1                1734                    person wearing camouflage pants
# 2                1734                    person wearing camouflage pants
# 3                3961                                    white mountains
# 4                3961                                    white mountains
# 5                3961                                    white mountains
# 6                3961                                    white mountains
# 7                3961                                    white mountains
# 8                3961                                    white mountains
# 9                3961                                    white mountains
# 10               3961                                    white mountains
# 11               3961                                    white mountains
# 12               3961                                    white mountains
# 13               3961                                    white mountains
# 14               3961                                    white mountains
# 15               5891                                                NaN
# 16               5891                                                NaN
# 17               1101                  woman walking on mountain pathway
# 18              22013                           brown deer beside plants
# 19              22013                           brown deer beside plants
# 20              22013                           brown deer beside plants
# 21              22013                           brown deer beside plants
# 22              22013                           brown deer beside plants
# 23               9536                          bee in fornt of Sunflower
# 24               5956            man standing on rocky river under cliff
# 25               5956            man standing on rocky river under cliff
# 26               5956            man standing on rocky river under cliff
# 27               5956            man standing on rocky river under cliff
# 28               5956            man standing on rocky river under cliff
# 29               5956            man standing on rocky river under cliff
# ...               ...                                                ...
# 4796            36836  silhouette of person holding flashlight during...
# 4797             4396  long-exposure photography of waterfalls during...
# 4798             4396  long-exposure photography of waterfalls during...
# 4799             7205      shallow focus photography of red petal flower
# 4800             7205      shallow focus photography of red petal flower
# 4801             7205      shallow focus photography of red petal flower
# 4802             5567                                 red petaled flower
# 4803             1067                   yellow flower in tilt shift lens
# 4804            34583                             three white plant pots
# 4805            11859                   jellyfish underwater photography
# 4806            85230           pink cherry blossom tree under sunny sky
# 4807            19041            canyon at daytime low angle photography
# 4808             2000  person standing on seashore under green sky wi...
# 4809             1081  snow covered mountain near body of water durin...
# 4810             3181                          pink flower in macro shot
# 4811             2180    aerial view of city buildings during night time
# 4812             3506                person holding orange pealed flower
# 4813            20655                          silhouette photo of plant
# 4814            67543                                    Antelope Canyon
# 4815            67543                                    Antelope Canyon
# 4816            10327            close-up photography yellow rose flower
# 4817            19636                   wheat field under clear blue sky
# 4818            19636                   wheat field under clear blue sky
# 4819             9883                        grey bird and yellow flower
# 4820             9883                        grey bird and yellow flower
# 4821             9883                        grey bird and yellow flower
# 4822             9883                        grey bird and yellow flower
# 4823             6457               snow covered mountain under blue sky
# 4824             6457               snow covered mountain under blue sky
# 4825             2602                 sunflower field during golden hour
#
#                                       photo_description
# 0     doors off helicopter ride at sunset..... price...
# 1     doors off helicopter ride at sunset..... price...
# 2     doors off helicopter ride at sunset..... price...
# 3     Autumn is just around the corner, you can smel...
# 4     Autumn is just around the corner, you can smel...
# 5     Autumn is just around the corner, you can smel...
# 6     Autumn is just around the corner, you can smel...
# 7     Autumn is just around the corner, you can smel...
# 8     Autumn is just around the corner, you can smel...
# 9     Autumn is just around the corner, you can smel...
# 10    Autumn is just around the corner, you can smel...
# 11    Autumn is just around the corner, you can smel...
# 12    Autumn is just around the corner, you can smel...
# 13    Autumn is just around the corner, you can smel...
# 14    Autumn is just around the corner, you can smel...
# 15    The Milky Way from Glacier Point in Yosemite N...
# 16    The Milky Way from Glacier Point in Yosemite N...
# 17    Buat yg ingin naik ke gunung tapi fisikga kuat...
# 18    This image was taken near a lake in South East...
# 19    This image was taken near a lake in South East...
# 20    This image was taken near a lake in South East...
# 21    This image was taken near a lake in South East...
# 22    This image was taken near a lake in South East...
# 23    Bees work very hard and do a fantastic job of ...
# 24                                     Chasing Memories
# 25                                     Chasing Memories
# 26                                     Chasing Memories
# 27                                     Chasing Memories
# 28                                     Chasing Memories
# 29                                     Chasing Memories
# ...                                                 ...
# 4796                                                NaN
# 4797  The Big Trip | Vernal Fall in Yosemite Nationa...
# 4798  The Big Trip | Vernal Fall in Yosemite Nationa...
# 4799                                                NaN
# 4800                                                NaN
# 4801                                                NaN
# 4802                         Sheffield General Cemetery
# 4803    Spring awakening – yellow flowers blossom bloom
# 4804                               Blue, red and yellow
# 4805                                                NaN
# 4806                                                NaN
# 4807                          Sandstone Antelope Canyon
# 4808                                                NaN
# 4809  In the midst of the Canadian Rocky Mountains i...
# 4810  Food Photographer! 🍴Follow me on instagram for...
# 4811             Street grid in Chicago, United States.
# 4812                                                NaN
# 4813                             Beijing Horizon sunset
# 4814  If you like and use my photos, I would love a ...
# 4815  If you like and use my photos, I would love a ...
# 4816  Flowers always make people better, happier, an...
# 4817                                                NaN
# 4818                                                NaN
# 4819                                                NaN
# 4820                                                NaN
# 4821                                                NaN
# 4822                                                NaN
# 4823                Clouds and blue sky over a mountain
# 4824                Clouds and blue sky over a mountain
# 4825                                    Warm sunflowers
#
# [4826 rows x 9 columns]

# %%
color_table_1 = color_table[color_table.color.isin(top_colors)]
keyword_table_1 = keyword_table[keyword_table.keyword.isin(top_keywords)]
combinedata = pd.merge(color_table_1, keyword_table_1, on='photo_id', how='inner')
combinedata = pd.merge(combinedata, camera_table, on='photo_id', how='inner')
combinedata = combinedata.drop_duplicates()
url_table = datasets['photos'][['photo_id','photo_url','stats_downloads','ai_description','photo_description']]
combinedata = pd.merge(combinedata, url_table, on='photo_id', how='inner')
combinedata
rec_photo = combinedata.loc[combinedata.groupby(['color',
       'photo_location_country','keyword'])['stats_downloads'].idxmax()]
rec_photo = rec_photo[rec_photo.photo_location_country.isin(['United States', 
        'Italy',  'France'])]

rec_photo.shape

# %%
combinedata.to_csv(r'photoRecommendation.csv', index = False)
infotable_update.to_csv(r'predictionModel.csv', index = False)
featured_photo.to_csv(r'featuredPhoto.csv', index = False)
keyword_photo.to_csv(r'keywordFeatured.csv', index = False)

# %% [markdown]
# # Creating Barplots

# %%
import pandas as pd
import matplotlib.pyplot as plt
from subprocess import check_output,CalledProcessError
from bs4 import BeautifulSoup
import requests

# %%
df= pd.read_csv('predictionModel.csv')

for i in range(len(df)):
    l = df['color'][i]
    j = df['keyword'][i]
    k = df['camera'][i]
    x = []
    y = []
    x.append(df['Nation1'][i])
    x.append(df['Nation2'][i])
    x.append(df['Nation3'][i])
    x.append(df['Nation4'][i])
    x.append(df['Nation5'][i])
    y.append(float(df['nation1ratio'][i]))
    y.append(float(df['nation2ratio'][i]))
    y.append(float(df['nation3ratio'][i]))
    y.append(float(df['nation4ratio'][i]))
    y.append(float(df['nation5ratio'][i]))
    
    plt.rcParams.update({'font.size': 20})
    fig, ax = plt.subplots(figsize=(10,6))
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.bar(x,y,color ="#1e467d")
    ax.set_ylim(top=1.0)
    ax.set_ylabel('Probability')
    for index, value in enumerate(y):
        plt.text(index-0.3, value+0.03, str(round(value,2)))
    plt.xticks(rotation=60)
    plt.tight_layout()
    plt.savefig("barplots/"+str(l)+"_"+str(j)+"_"+str(k)+'.png',dpi=1200)

# %% [markdown]
# # Download Unsplash Images

# %%
df1 = pd.read_csv('recommandPhotoHighest.csv')
c_l = ['France','Italy','United States']
import os
arr = os.listdir()
for i in range(len(df1)):
    url = df1['photo_url'][i]
    
    l = str(df1['color'][i])
    j = str(df1['keyword'][i])
#     k = str(df1['exif_camera_make'][i])
    if str(df1['photo_location_country'][i]) in c_l:
        o = "_".join(str(df1['photo_location_country'][i]).split())
    else:
        continue

    r = requests.get(url)
    page = BeautifulSoup(r.text)
    imglist = page.find_all("img")
    srcset = imglist[2]['srcset']
    picurl = srcset.split()[0]
    check_output("curl '"+picurl+"' -o "+l+"_"+j+"_"+o+".jpeg", shell=True)
